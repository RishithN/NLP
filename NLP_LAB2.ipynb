# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithN/NLP/blob/main/NLP_LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reading from Text file

# %%
import pandas as pd
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b47beab6-3cca-47ba-86b3-16b317cc4f08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b47beab6-3cca-47ba-86b3-16b317cc4f08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output= pd.read_csv('/content/files.txt',sep='\t')
print(output)
# Out:
#              Hi
# 0         hello
# 1  good morning

# %%
with open('/content/files.txt','r',encoding = 'utf-8') as f:
  text=f.read()
print(text)
# Out:
# Hi
# hello
# good morning

# %%
output = pd.read_csv('/content/spam.csv', encoding='latin-1')
print(output.head())
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
with open('/content/spam.csv', 'r', encoding='latin-1') as f:
    text1 = f.read()

print(text1[:1000])
# Out:
# v1,v2,,,
# ham,"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...",,,
# ham,Ok lar... Joking wif u oni...,,,
# spam,Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's,,,
# ham,U dun say so early hor... U c already then say...,,,
# ham,"Nah I don't think he goes to usf, he lives around here though",,,
# spam,"FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, å£1.50 to rcv",,,
# ham,Even my brother is not like to speak with me. They treat me like aids patent.,,,
# ham,As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune,,,
# ...

# %%
import PyPDF2
pdf = open('/content/Module1.pdf', 'rb')
reader = PyPDF2.PdfReader(pdf)
text = ""
for page in reader.pages:
    text += page.extract_text()
print(text)
pdf.close()
# Out:
# LLM for Question Generation and Validation to
# Enhance School Level Student Assessment
# Adithya D Varma
# Department of Computer Science
# and Engineering
# Amrita School of Computing
# Amrita Vishwa Vidyapeetham
# Amritapuri, India
# amenu4aie21104@am.students.amrita.eduSruthy Anand
# Center for Wireless Networks &
# Applications (WNA)
# Amrita Vishwa Vidyapeetham
# Amritapuri, India
# sruthyanand@am.amrita.eduAkshay Krishnan Thekkedath
# Department of Computer Science
# and Engineering
# Amrita School of Computing
# Amrita Vishwa Vidyapeetham
# Amritapuri, India
# amenu4aie21109@am.students.amrita.edu
# Kiran P
# Department of Computer Science
# and Engineering
# Amrita School of Computing
# Amrita Vishwa Vidyapeetham
# Amritapuri, India
# amenu4aie21175@am.students.amrita.eduNiranjan Prasanth
# Department of Computer Science
# and Engineering
# Amrita School of Computing
# Amrita Vishwa Vidyapeetham
# Amritapuri, India
# amenu4aie21148@am.students.amrita.eduSethuraman N Rao
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
input = requests.get('https://www.alliance.edu.in')

# %%
print(input)
# Out:
# <Response [200]>

# %%
input.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en"> \r\n<head>\r\n<link rel="canonical" href="https://www.alliance.edu.in/" />\r\n\t\t<title>Alliance University | Bangalore Campus </title>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta name="description" content="Alliance University Campus in Bangalore has state-of-the-art infrastructure with serene ambience. We offer graduate, post-graduate and certification courses.">\r\n    <meta name="keyword" content="alliance university campus, alliance university bangalore campus, alliance university city campus, alliance university campus area, alliance university central campus, alliance university btm layout campus, alliance btm campus">\r\n\t<meta name="google-site-verification" content="XI1MCM-3n3E5dvra-NV9ogVyfXCskOuBZv1WjIUeJik" />\r\n\t<meta name="facebook-domain-verification" content="dbcfzari3avtu79javik0x00ib8sgu" /
# ...

# %%
sb=BeautifulSoup(input.text,'html.parser')
sb
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://www.alliance.edu.in/" rel="canonical"/>
# <title>Alliance University | Bangalore Campus </title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Alliance University Campus in Bangalore has state-of-the-art infrastructure with serene ambience. We offer graduate, post-graduate and certification courses." name="description"/>
# <meta content="alliance university campus, alliance university bangalore campus, alliance university city campus, alliance university campus area, alliance university central campus, alliance university btm layout campus, alliance btm campus" name="keyword"/>
# <meta content="XI1MCM-3n3E5dvra-NV9ogVyfXCskOuBZv1WjIUeJik" name="google-site-verification">
# <meta content="dbcfzari3avtu79javik0x00ib8sgu" name="facebook-domain-verification">
# ...

# %%
sb=BeautifulSoup(input.text,'html.parser')
sb.find_all('h2')
# Out:
# []
